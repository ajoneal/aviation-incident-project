# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df16 = pd.read_csv('./data/2016_aviation.csv')

# %%
df16.head()
# Out:
#        NtsbNo EventType   Mkey             EventDate          City  \
# 0  CEN17FA064       ACC  94551  2016-12-31T18:45:00Z        Vienna
# 1  CEN17FA063       ACC  94550  2016-12-31T18:25:00Z      McKinney
# 2  GAA17CA108       ACC  94580  2016-12-31T18:00:00Z   Casa Grande
# 3  GAA17CA106       ACC  94559  2016-12-31T12:00:00Z       Palouse
# 4  CEN17LA066       ACC  94556  2016-12-31T08:40:00Z  Lee's Summit
#
#         State        Country ReportNo              N#  HasSafetyRec      Mode  \
# 0    Illinois  United States      NaN          N2806R         False  Aviation
# 1       Texas  United States      NaN  N4407T, N2889K         False  Aviation
# 2     Arizona  United States      NaN          N5897R         False  Aviation
# 3  Washington  United States      NaN          N260BD         False  Aviation
# 4    Missouri  United States      NaN          N120CG         False  Aviation
#
#       ReportType OriginalPublishedDate HighestInjuryLevel  FatalInjuryCount  \
# ...
